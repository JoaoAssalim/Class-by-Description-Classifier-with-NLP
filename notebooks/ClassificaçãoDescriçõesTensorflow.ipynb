# %%
import pandas as pd
import numpy as np
import spacy

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import tensorflow as tf
from tensorflow.keras.layers import TextVectorization, Embedding, Conv1D, MaxPooling1D, LSTM, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.callbacks import EarlyStopping

import nltk
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
stop_words = set(stopwords.words('portuguese'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\janna\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_excel('../data/DATA_FULL_TRAIN.xlsx')

# %%
df.head()
# Out:
#                                                Texto     Classe
# 0  SERVICO E LICENCAS DE SOFTWARE DE USO DO CALL CEN  MACHINERY
# 1  UPGRADE DO SISTEMA DE SEGURANCA DO SITE ALEXANDRE  MACHINERY
# 2  UPGRADE DO SISTEMA DE SEGURANCA DO SITE ALEXANDRE  MACHINERY
# 3                        REFRIGERADOR 342 L FF CLEAN  MACHINERY
# 4                        REFRIGERADOR 342 L FF CLEAN  MACHINERY

# %%
nlp = spacy.load("pt_core_news_sm")

def preprocess_text(text, stop_words=[]):
    doc = nlp(text)
    lemmatized_words = [token.lemma_.lower() for token in doc if token.lemma_ not in stop_words and len(token.lemma_) > 1]
    processed_text = ' '.join(lemmatized_words)
    return processed_text

# %%
df['Texto'] = df['Texto'].apply(preprocess_text)

# %%
X = df['Texto']
y = df['Classe']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42, stratify=y)

# %%
tokenizer = Tokenizer(
    num_words=None,
    filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n',
    lower=True,
    split=' ',
)

# %%
sequences = tokenizer.fit_on_texts(X_train)
print(tokenizer.word_index)
# Out:
# {'de': 1, 'cadeira': 2, 'em': 3, 'mca': 4, 'adm': 5, 'fixa': 6, 'mod': 7, 'c': 8, 'gb': 9, 'cco': 10, 'dell': 11, 'mesa': 12, 'thinkpad': 13, 'monitor': 14, 'giratória': 15, '1': 16, 'notebook': 17, 'com': 18, 'painel': 19, 'para': 20, 'aco': 21, 'gavetas': 22, 'ar': 23, 'microcomputador': 24, '64': 25, 'madeira': 26, 'portas': 27, 'i5': 28, 'serie': 29, 'infantil': 30, 'giratoria': 31, 'carteira': 32, 'escolar': 33, 'lenovo': 34, 'tipo': 35, 'poltrona': 36, 'iphone': 37, 'atendimento': 38, 'gaveteiro': 39, 'balcão': 40, 'armario': 41, 'lugares': 42, 'padrão': 43, '5': 44, 'inox': 45, 'standard': 46, 'vostro': 47, 'air': 48, '2': 49, 'formica': 50, 'linha': 51, 'black': 52, 'ipad': 53, '8350u': 54, 'licença': 55, 'hp': 56, 'caixa': 57, 'pa': 58, 'kit': 59, '14': 60, 'o': 61, 'executiva': 62, 'base': 63, 't480': 64, 'core': 65, 'instalação': 66, 'smartphone': 67, 'p': 68, '12': 69, 'longarina': 70, 'tecido': 71, 'sob': 72, 'eletrico': 73, 'estrutura': 74, 'condicionado': 75, 'medida': 76, 'aquarela': 77, 'porta': 78, 'leitor': 79, 'trabalho': 80, 'metalico': 81, 'cinza': 82, 'led': 83, 'comando': 84, 'do': 85, 'nc': 86, 'office': 87, 'num': 88, 'bomba': 89, 'symbol': 90, 'mc35': 91, 'condicionador': 92, 'me': 93, 'optiplex': 94, 'estofamento': 95, 'arquivo': 96, '18': 97, 'latitude': 98, 'intel': 99, 'wifi': 100, 'aço': 101, 'plastico': 102, 'gray': 103, 'space': 104, '4th': 105, 'lg': 106, 'hd': 107, 'motor': 108, 'portatil': 109, 't410': 110, 'estofada': 111, 'cartaz': 112, 'samsung': 113, 'pasta': 114, 'split': 115, 'sistema': 116, 'suspensa': 117, 'gertec': 118, '3': 119, 'preta': 120, '4': 121, 'pin': 122, 'reforma': 123, 'bancada': 124, 'código': 125, 'ventilador': 126, 'itapevi': 127, 'garantia': 128, 'metalica': 129, 'dimensoes': 130, 'windows': 131, '3420': 132, '128': 133, 'digital': 134, 'obra': 135, 'sngl': 136, 'pad': 137, 'switch': 138, 'persiana': 139, 'mvl': 140, 'estação': 141, 'compra': 142, '48': 143, 'balanca': 144, 'divisoria': 145, 'modelo': 146, 'autenticadora': 147, 'vidro': 148, '16002': 149, 'winsvrcal': 150, 'dvccal': 151, 'tv': 152, '6': 153, 'uso': 154, 'plus': 155, 'serv': 156, 'software': 157, 't14': 158, 'xr': 159, 'mh6m3br': 160, 'user': 161, 'laptop': 162, 'wi': 163, '19': 164, 'fi': 165, 'mdf': 166, 'licspak': 167, 'securit': 168, 'impressora': 169, 'camera': 170, 'apoio': 171, 'civil': 172, 'lt': 173, 'perto': 174, 'modulo': 175, 'gerente': 176, 'auto': 177, 'transportador': 178, 'estante': 179, '3070': 180, 'panini': 181, '70': 182, 's': 183, 'couro': 184, 'melamina': 185, 'bracos': 186, 'ii': 187, 'quadro': 188, 'open': 189, 'e1916h': 190, 'leitora': 191, 'divisória': 192, 'cor': 193, 'veículo': 194, 'courvim': 195, 'revestimento': 196, 'suporte': 197, 'estofado': 198, 'bateria': 199, 'computador': 200, 'auditório': 201, 'centrifugo': 202, 'cnb': 203, 'preto': 204, 'branco': 205, 'smart': 206, 'firewall': 207, '3470': 208, 'correia': 209, 'lcd': 210, 'std': 211, 'caminhao': 212, 'nobreak': 213, 'sicoob': 214, 'btu': 215, '000': 216, 'sala': 217, '60': 218, 'komeco': 219, 'aluminio': 220, 'flip': 221, 't490': 222, 'calculadora': 223, 'pro': 224, 'desktop': 225, 'br': 226, 't420': 227, 'visita': 228, 'i3': 229, 'marrom': 230, 'vision': 231, '8365u': 232, 'blu': 233, '10': 234, 'contadora': 235, '2000': 236, 'vertical': 237, 'projeto': 238, 'cavaletti': 239, '20': 240, 'server': 241, 'versa': 242, 'fechadura': 243, 'balcao': 244, 'autoplan': 245, 'computadores': 246, '\xa0': 247, 'ppc930': 248, 'btus': 249, 'tanque': 250, '200': 251, '0': 252, 'pinpad': 253, 'voko': 254, 'no': 255, 'instalações': 256, 'volante': 257, 'cvt': 258, 'armário': 259, 'atm': 260, 'brac': 261, 'rod': 262, 'acer': 263, 'video': 264, 'valvula': 265, 'verde': 266, 'central': 267, '32': 268, 'tampo': 269, 'cal': 270, 'rodizios': 271, 'ca': 272, 'cadeiras': 273, 'dvr': 274, 'braço': 275, '43103': 276, 'manual': 277, 'p11': 278, 'filtro': 279, '16': 280, 'horizontal': 281, 'ap': 282, 'polt': 283, 'maquina': 284, 'tb': 285,  ...

# %%
vectorizer = TextVectorization(
    max_tokens=20000,
    standardize='lower_and_strip_punctuation',
    split='whitespace',
    output_mode='int',
    output_sequence_length=100
)

vectorizer.adapt(X_train)

# %%
X_train = vectorizer(np.array([[s] for s in X_train])).numpy()
X_test = vectorizer(np.array([[s] for s in X_test])).numpy()

# %%
word_index = vectorizer.get_vocabulary()

# %%
vectorizer("SERVICO LICENCAS DE SOFTWARE DE USO DO CALL CEN")
# Out:
# <tf.Tensor: shape=(9,), dtype=int64, numpy=array([ 576, 3582,    2,  148,    2,  160,   82, 2222,    1], dtype=int64)>

# %%
le = LabelEncoder()
y_train_encoded = le.fit_transform(y_train)
y_test_encoded = le.transform(y_test)

num_labels = len(le.classes_)

# %%
model = Sequential([
    # Camada de Embedding para transformar números inteiros (índices de palavras) em vetores densos
    Embedding(input_dim=len(vectorizer.get_vocabulary()), output_dim=50, input_length=100),
    
    # Camada Conv1D para convolução unidimensional sobre a sequência de entrada
    Conv1D(filters=128, kernel_size=5, padding='same', activation='relu'),
    
    # Camada MaxPooling1D para reduzir o tamanho da entrada pela extração do máximo da janela
    MaxPooling1D(pool_size=2),
    
    # Dropout para regularização, desativando aleatoriamente 50% dos neurônios durante o treinamento
    Dropout(0.5),
    
    # Camada Bidirectional LSTM para capturar dependências de sequência em ambas as direções
    Bidirectional(LSTM(units=64, dropout=0.2, recurrent_dropout=0.3, return_sequences=True)),
    
    # Outra camada Bidirectional LSTM, agora sem return_sequences, para processar a saída da primeira camada LSTM
    Bidirectional(LSTM(units=32)),
    
    # Dropout adicional para a segunda camada LSTM
    Dropout(0.2),
    
    # Camada Dense totalmente conectada com ativação 'relu' para aprendizado de características
    Dense(64, activation='relu'),
    
    # Camada Dense de saída com ativação 'softmax' para classificação multiclasse
    Dense(num_labels, activation='softmax')
])

# %%
# Compilar o modelo com otimizador 'adam' e função de perda 'sparse_categorical_crossentropy' para classificação multiclasse
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train_encoded, epochs=8, validation_split=0.2)
# Out:
# Epoch 1/8
# 1218/1218 [==============================] - 49s 36ms/step - loss: 0.4473 - accuracy: 0.8452 - val_loss: 0.2380 - val_accuracy: 0.9306
# Epoch 2/8
# 1218/1218 [==============================] - 44s 36ms/step - loss: 0.1769 - accuracy: 0.9494 - val_loss: 0.1993 - val_accuracy: 0.9436
# Epoch 3/8
# 1218/1218 [==============================] - 44s 37ms/step - loss: 0.1174 - accuracy: 0.9662 - val_loss: 0.1835 - val_accuracy: 0.9468
# Epoch 4/8
# 1218/1218 [==============================] - 45s 37ms/step - loss: 0.0904 - accuracy: 0.9747 - val_loss: 0.1873 - val_accuracy: 0.9481
# Epoch 5/8
# 1218/1218 [==============================] - 45s 37ms/step - loss: 0.0766 - accuracy: 0.9777 - val_loss: 0.1912 - val_accuracy: 0.9517
# Epoch 6/8
# 1218/1218 [==============================] - 45s 37ms/step - loss: 0.0655 - accuracy: 0.9802 - val_loss: 0.2112 - val_accuracy: 0.9461
# Epoch 7/8
# 1218/1218 [==============================] - 45s 37ms/step - loss: 0.0595 - accuracy: 0.9817 - val_loss: 0.2241 - val_accuracy: 0.9488
# Epoch 8/8
# 1218/1218 [==============================] - 45s 37ms/step - loss: 0.0538 - accuracy: 0.9826 - val_loss: 0.2295 - val_accuracy: 0.9478

# %%
loss, accuracy = model.evaluate(X_test, y_test_encoded)
print(f'Acurácia: {accuracy * 100:.2f}%')
# Out:
# 653/653 [==============================] - 5s 7ms/step - loss: 0.2451 - accuracy: 0.9447
# Acurácia: 94.47%
